# %% [markdown]
# # Venkatalaksmi Bandaru

# %% [markdown]
# # **Task -3 : Exploraratory Data analysis - Retail**

# %%
#Importing Some Library
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
# %matplotlib inline

# %%
#Import dataset and head of the data
df = pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
#Check the shape of dataset
df.shape
# Out:
# (9994, 13)

# %%
#Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#check if there are any null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Check the mean,max,min of dataset
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Check duplicate
df.duplicated().sum()
# Out:
# 17

# %%
#drop duplicate
data.drop_duplicates(inplace=True)
#now again check dupicate
data.duplicated().sum()
# Out:
# 0

# %%
df[['Ship Mode', 'Segment', 'Country','City','State','Region','Category','Sub-Category']].describe()
# Out:
#              Ship Mode   Segment  ...         Category Sub-Category
# count             9994      9994  ...             9994         9994
# unique               4         3  ...                3           17
# top     Standard Class  Consumer  ...  Office Supplies      Binders
# freq              5968      5191  ...             6026         1523
#
# [4 rows x 8 columns]

# %%
#Correlation 
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# # Data visualization

# %%
#Heatmap of correlation
sns.heatmap(df.corr(), annot=True)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %%
df_state=df.groupby(['State'])[['Quantity','Sales','Discount','Profit']].mean()
df_state.head()
# Out:
#             Quantity       Sales  Discount     Profit
# State
# Alabama     4.196721  319.846557  0.000000  94.865989
# Arizona     3.848214  157.508933  0.303571 -15.303235
# Arkansas    4.000000  194.635500  0.000000  66.811452
# California  3.831584  228.729451  0.072764  38.171608
# Colorado    3.807692  176.418231  0.316484 -35.867351

# %%
df_state=df.groupby(['State'])[['Quantity','Sales','Discount','Profit']].describe()
df_state.head()
# Out:
#            Quantity                      ...    Profit
#               count      mean       std  ...       50%       75%        max
# State                                    ...
# Alabama        61.0  4.196721  2.606528  ...  16.87500  71.38980  1459.2000
# Arizona       224.0  3.848214  2.231892  ...   2.53365  13.41360   211.4955
# Arkansas       60.0  4.000000  1.965809  ...  18.34080  71.62770   843.1706
# California   2001.0  3.831584  2.280158  ...  13.30560  35.62380  1906.4850
# Colorado      182.0  3.807692  2.197775  ...   3.12480  10.40175   247.9960
#
# [5 rows x 32 columns]

# %%
sp=df.groupby('State')['Profit'].sum()
sp.head()
# Out:
# State
# Alabama        5786.8253
# Arizona       -3427.9246
# Arkansas       4008.6871
# California    76381.3871
# Colorado      -6527.8579
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(16,8))
sns.barplot(x=sp.index, y=sp.values)
plt.xticks(rotation=60)
plt.ylabel('Profit')
plt.show()

# %%
sns.pairplot(df, hue='Region')

# %%
sns.pairplot(df, hue='Category')

# %%
sns.countplot('Segment', data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
state = df['State'].value_counts()
plt.figure(figsize=(15,16))
sns.countplot(x=df['State'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
df.groupby('Category')['Profit'].sum().plot.pie(autopct='%1.1f%%', shadow=True)
plt.title('Category Wise Profit Analysis', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Category Wise Profit Analysis')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Category', hue='Region', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
order=df.groupby(['State', 'City']).size().reset_index(name='total_orders')
order[order['total_orders']==order['total_orders'].min()]
# Out:
#           State            City  total_orders
# 21     Arkansas          Conway             1
# 27     Arkansas          Rogers             1
# 28     Arkansas      Springdale             1
# 31   California         Antioch             1
# 39   California  Citrus Heights             1
# ..          ...             ...           ...
# 549        Utah          Layton             1
# 572  Washington          Auburn             1
# 578  Washington         Everett             1
# 600   Wisconsin        Waukesha             1
# 603     Wyoming        Cheyenne             1
#
# [78 rows x 3 columns]

# %%
plt.figure(figsize=(15,13))
df.groupby('State')['Sales'].sum().plot.pie(autopct='%1.1f%%')
plt.title('Sale Analysis', fontsize=20)
plt.show()
